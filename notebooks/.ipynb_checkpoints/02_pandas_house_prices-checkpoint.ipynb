# %% [markdown]
# # Pandas Foundations — House Prices Dataset
# ## Exploratory Data Analysis (EDA) for Regression
#
# **Dataset:** Ames Housing (2,930 houses, 80 features)
# **Goal:** Predict `SalePrice` — understand the data before modeling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/raw/AmesHousing.csv")
print("Shape: ", df.shape)
print("Memory Usage: ", df.memory_usage(deep=True).sum() / 1024**2, "MB")
# Out:
# Shape:  (2930, 82)
# Memory Usage:  6.915376663208008 MB

# %%
# Data types
df.dtypes.value_counts()
# Out:
# str        43
# int64      28
# float64    11
# Name: count, dtype: int64

# %%
# Target Variable
print("Sales Stata")
print(df["SalePrice"].describe().round(2))
print(f"Min: {df["SalePrice"].min()}")
print(f"Max: {df["SalePrice"].max()}")
print(f"Median: {df["SalePrice"].median()}")
# Out:
# Sales Stata
# count      2930.00
# mean     180796.06
# std       79886.69
# min       12789.00
# 25%      129500.00
# 50%      160000.00
# 75%      213500.00
# max      755000.00
# Name: SalePrice, dtype: float64
# Min: 12789
# Max: 755000
# Median: 160000.0

# %% [markdown]
# ## Missing Value Analysis

# %%
# count + percentage of missing values per column
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)

missing_df = pd.DataFrame({
    "missing_count": missing,
    "missing_pct": missing_pct
}).query("missing_count > 0").sort_values("missing_pct", ascending=False)

print("Columns with missing data: ", len(missing_df))
missing_df.head(20)
# Out:
# Columns with missing data:  27
#                 missing_count  missing_pct
# Pool QC                  2917        99.56
# Misc Feature             2824        96.38
# Alley                    2732        93.24
# Fence                    2358        80.48
# Mas Vnr Type             1775        60.58
# Fireplace Qu             1422        48.53
# Lot Frontage              490        16.72
# Garage Qual               159         5.43
# Garage Cond               159         5.43
# Garage Yr Blt             159         5.43
# Garage Finish             159         5.43
# Garage Type               157         5.36
# Bsmt Exposure              83         2.83
# BsmtFin Type 2             81         2.76
# Bsmt Cond                  80         2.73
# Bsmt Qual                  80         2.73
# BsmtFin Type 1             80         2.73
# Mas Vnr Area               23         0.78
# Bsmt Full Bath              2         0.07
# Bsmt Half Bath              2         0.07

# %%
# Visualize the missing data
fig, ax = plt.subplots(figsize=(10, 5))
missing_df["missing_pct"].head(15).plot(kind="barh", ax=ax, color="#378ADD")
ax.set_xlabel("Missing %")
ax.set_title("Top 15 columns with missing data - Ames Housing")
ax.invert_yaxis()
plt.tight_layout()
plt.savefig("../artifacts/missing_values.png", dpi=150)
plt.show()
print("Saved to artifacts/missing_values.png")
# Out:
# Saved to artifacts/missing_values.png

# %% [markdown]
# ## DataFrame Selection & Filtering

# %%
# select specific columns
cols = ["Gr Liv Area", "Bedroom AbvGr", "Year Built", "Overall Qual", "SalePrice"]
subs = df[cols].copy()
subs.head()
# Out:
#    Gr Liv Area  Bedroom AbvGr  Year Built  Overall Qual  SalePrice
# 0         1656              3        1960             6     215000
# 1          896              2        1961             5     105000
# 2         1329              3        1958             6     172000
# 3         2110              3        1968             7     244000
# 4         1629              3        1997             5     189900

# %%
# Filter rows — boolean indexing (same concept as NumPy masking)
expensive = df[df["SalePrice"] > 300_000]
print("Prices over $300k:", len(expensive))

# Multi-condition filter
high_quality_large = df[
    (df["Overall Qual"] >= 8) &
    (df["Gr Liv Area"] > 2000)
]
print("High Quality + Large:", len(high_quality_large))
print("Average Price:", high_quality_large["SalePrice"].mean().round(2))
# Out:
# Prices over $300k: 230
# High Quality + Large: 191
# Average Price: 360472.79

# %%
# .loc vs .iloc — the two indexers to know
# .loc → label-based (column names, index labels)
# .iloc → position-based (row/col numbers)

print("loc - first 3 rows, specific columns:")
print(df.loc[:2, ["Gr Liv Area", "SalePrice"]])

print("\niloc - rows 5-8, first 4 columns:")
print(df.iloc[5:9, :4])
# Out:
# loc - first 3 rows, specific columns:
#    Gr Liv Area  SalePrice
# 0         1656     215000
# 1          896     105000
# 2         1329     172000
#
# iloc - rows 5-8, first 4 columns:
#    Order        PID  MS SubClass MS Zoning
# 5      6  527105030           60        RL
# 6      7  527127150          120        RL
# 7      8  527145080          120        RL
# 8      9  527146030          120        RL

# %% [markdown]
# ## GroupBy - Finding Price Drivers

# %%
# Average sale price by overall quality rating (1-10)
price_by_quality = (
    df.groupby("Overall Qual")["SalePrice"]
    .agg(["mean", "median", "count"])
    .round(0)
    .rename(columns={"mean": "avg_price", "median": "median_price", "cont": "num_houses"})
)

print(price_by_quality)
# Out:
#               avg_price  median_price  count
# Overall Qual
# 1               48725.0       50150.0      4
# 2               52325.0       57625.0     13
# 3               83186.0       81200.0     40
# 4              106485.0      105000.0    226
# 5              134753.0      133000.0    825
# 6              162130.0      159500.0    732
# 7              205026.0      200000.0    602
# 8              270914.0      264530.0    350
# 9              368337.0      360000.0    107
# 10             450217.0      451950.0     31

# %%
# Visualise - quality vs price
fig, ax = plt.subplots(figsize=(9,4))
price_by_quality["avg_price"].plot(kind="bar", ax=ax, color="#1D9E75", edgecolor="white")
ax.set_xlabel("Overall Quality (1=Poor, 10=Excellent)")
ax.set_ylabel("Average Sale Price ($)")
ax.set_title("House Quality vs Average Sale Price - Ames Housing")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"${x:,.0f}"))
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig("../artifacts/quality_vs_price.png", dpi=150)
plt.show()

# %%
# Numeric correlation with SalePrice — find the top features
numeric_df = df.select_dtypes(include=[np.number])
correlations = numeric_df.corr()["SalePrice"].drop("SalePrice").abs().sort_values(ascending=False)

print("Top 10 features correlated with SalePrice:")
print(correlations.head(10).round(3))
# Out:
# Top 10 features correlated with SalePrice:
# Overall Qual      0.799
# Gr Liv Area       0.707
# Garage Cars       0.648
# Garage Area       0.640
# Total Bsmt SF     0.632
# 1st Flr SF        0.622
# Year Built        0.558
# Full Bath         0.546
# Year Remod/Add    0.533
# Garage Yr Blt     0.527
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Section 2 - Missing Value Strategy & Cleaning

# %%
# Classify missing columns into two groups
# Structural Nan - Nan means Not applicable (no pool, no alley, no garage)
# This get filled with "None" (categorical) or 0 (numerical)

structural_cat = [
    "Pool QC", "Misc Feature", "Alley", "Fence",
    "Fireplace Qu", "Garage Type", "Garage Finish",
    "Garage Qual", "Garage Cond", "Bsmt Qual", "Bsmt Cond",
    "Bsmt Exposure", "BsmtFin Type 1", "BsmtFin Type 2",
    "Mas Vnr Type",
]

structural_num = [
    "Garage Yr Blt", "Garage Area", "Garage Cars",
    "BsmtFin SF 1", "BsmtFin SF 2", "Bsmt Unf SF",
    "Total Bsmt SF", "Bsmt Full Bath", "Bsmt Half Bath",
    "Mas Vnr Area",
]

# True missing - needs imputation
true_missing_num = ["Lot Frontage"]
true_missing_cat = ["Electrical"]

print("Structural categorical:", len(structural_cat))
print("Structural numeric:", len(structural_num))
print("True missing numeric:", true_missing_num)
print("True missing categorical:", true_missing_cat)
# Out:
# Structural categorical: 15
# Structural numeric: 10
# True missing numeric: ['Lot Frontage']
# True missing categorical: ['Electrical']

# %%
# Apply the strategy - work on a copy, never mutate raw data
df_clean = df.copy()

# Structural categoricals → "None"
for col in structural_cat:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].fillna("None")

# Structural numerics → 0 (no garage = 0 cars, 0 area)
for col in structural_num:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].fillna(0)

# True missing numeric → median (robust to outliers)
df_clean["Lot Frontage"] = df_clean["Lot Frontage"].fillna(df_clean["Lot Frontage"].median())

# True missing categorical → mode
df_clean["Electrical"] = df_clean["Electrical"].fillna(df_clean["Electrical"].mode()[0])

# Verify
remaining = df_clean.isnull().sum().sum()
print("Missing values remaining:", remaining)
print("✓ Clean" if remaining == 0 else "✗ Still has missing values")
# Out:
# Missing values remaining: 0
# ✓ Clean

# %% [markdown]
# ## Section 3 - Feature Engineering

# %%
# Engineer new features - combine existing ones to create stronger signal
df_clean["house_age"] = df_clean["Yr Sold"] - df_clean["Year Built"]
df_clean["remodel_age"] = df_clean["Yr Sold"] - df_clean["Year Remod/Add"]
df_clean["total_bathrooms"] = (
    df_clean["Full Bath"] +
    df_clean["Half Bath"] * 0.5 +
    df_clean["Bsmt Full Bath"] +
    df_clean["Bsmt Half Bath"] * 0.5
)
df_clean["total_sf"] = (
    df_clean["Total Bsmt SF"] +
    df_clean["1st Flr SF"] +
    df_clean["2nd Flr SF"]
)
df_clean["has_garage"] = (df_clean["Garage Area"] > 0).astype(int)
df_clean["has_pool"] = (df_clean["Pool Area"] > 0).astype(int)
new_features = ["house_age", "remodel_age", "total_bathrooms", "total_sf", "has_garage", "has_pool"]
print("New features created:")
df_clean[new_features].describe().round(2)
# Out:
# New features created:
#        house_age  remodel_age  total_bathrooms  total_sf  has_garage  has_pool
# count    2930.00      2930.00          2930.00   2930.00     2930.00   2930.00
# mean       36.43        23.52             2.22   2546.27        0.95      0.00
# std        30.29        20.86             0.81    804.35        0.23      0.07
# min        -1.00        -2.00             1.00    334.00        0.00      0.00
# 25%         7.00         4.00             1.50   2000.00        1.00      0.00
# 50%        34.00        15.00             2.00   2450.00        1.00      0.00
# 75%        54.00        42.75             2.50   2990.00        1.00      0.00
# max       136.00        60.00             7.00  11752.00        1.00      1.00

# %%
# Validate the new features correlate better than originals
new_corr = df_clean[new_features + ["SalePrice"]].corr()["SalePrice"].drop("SalePrice").abs().sort_values(ascending=False)
print("New feature correlations with SalePrice:")
print(new_corr.round(3))

# Compare total_sf vs individual floor areas
orig_corr = df_clean[["1st Flr SF", "2nd Flr SF", "Total Bsmt SF", "SalePrice"]].corr()["SalePrice"].drop("SalePrice")
print("\nOriginal floor correlations:")
print(orig_corr.round(3))
# Out:
# New feature correlations with SalePrice:
# total_sf           0.793
# total_bathrooms    0.636
# house_age          0.559
# remodel_age        0.535
# has_garage         0.226
# has_pool           0.088
# Name: SalePrice, dtype: float64
#
# Original floor correlations:
# 1st Flr SF       0.622
# 2nd Flr SF       0.269
# Total Bsmt SF    0.633
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Section 4 - Categorical Encoding

# %%
# Ordinal encoding - Overall Qual is already numeric (1-10), good
# But some quality columns are strings: Ex/Gd/TA/Fa/Po
quality_map = {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "None": 0}

quality_cols = ["Exter Qual", "Exter Cond", "Bsmt Qual", "Bsmt Cond",
                "Heating QC", "Kitchen Qual", "Fireplace Qu",
                "Garage Qual", "Garage Cond", "Pool QC"]

for col in quality_cols:
    if col in df_clean.columns:
        df[col] = df[col].map(quality_map).fillna(0).astype(int)

encoded_cols = [c for c in df_clean.columns if c.endswith("_enc")]
print("Encoded quality columns:", encoded_cols)
df_clean[encoded_cols].head()
# Out:
# Encoded quality columns: []
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# One-hot encoding for unordered categoricals
ohe_cols = ["Neighborhood", "House Style", "Sale Type", "Sale Condition"]
df_encoded = pd.get_dummies(df_clean, columns=ohe_cols, drop_first=True)

print("Shape before OHE:", df_clean.shape)
print("Shape after OHE: ", df_encoded.shape)
print(f"New columns added: {df_encoded.shape[1] - df_clean.shape[1]}")
# Out:
# Shape before OHE: (2930, 88)
# Shape after OHE:  (2930, 132)
# New columns added: 44

# %% [markdown]
# ## Section 5 - Final Feature Matrix

# %%
# Select final numeric features for modeling
# (dropping raw string columns and ID cols)

string_cols = df_encoded.select_dtypes(
    include=["object", "string"]
).columns.tolist()

drop_cols = (
    ["Order", "PID", "SalePrice"] +
    quality_cols +
    ohe_cols +
    string_cols
)

feature_cols = [c for c in df_encoded.columns if c not in drop_cols]

X = df_encoded[feature_cols].astype(float)
y = df_encoded["SalePrice"]

print("X shape:", X.shape)
print("y shape:", y.shape)
print("\nSample features:", feature_cols[:10])
print(f"\nTotal features going into model: {X.shape[1]}")
# Out:
# X shape: (2930, 90)
# y shape: (2930,)
#
# Sample features: ['MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2']
#
# Total features going into model: 90

# %%
# Save processed data - raw data never gets modified, processed data gets saved here
X.to_csv("../data/processed/X_features.csv", index=False)
y.to_csv("../data/processed/y_target.csv", index=False)

print("Saved:")
print("  data/processed/X_features.csv")
print("  data/processed/y_target.csv")
print("\nThis is what goes into sklearn next session.")
# Out:
# Saved:
#   data/processed/X_features.csv
#   data/processed/y_target.csv
#
# This is what goes into sklearn next session.
